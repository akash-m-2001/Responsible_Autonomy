# %%
# !pip install transformers datasets scikit-learn matplotlib seaborn numpy pandas
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.11/site-packages (4.57.3)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.11/site-packages (4.4.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.11/site-packages (0.13.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (1.24.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.11/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: httpx<1.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2023.9.2)
# Requirement already satisfied: scipy>=1.5.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.0.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.4)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)

# %%
import os
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import re

from transformers import AutoTokenizer, AutoModelForSequenceClassification

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA device:", torch.cuda.get_device_name(0))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# PyTorch version: 2.6.0+cu124
# CUDA available: True
# CUDA device: NVIDIA A100-SXM4-80GB
# device(type='cuda')

# %%
MODEL_DIR = "prompt_injection_roberta_base"

tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_DIR)
model.to(device)
model.eval()

print("Loaded model from:", MODEL_DIR)
# Out:
# Loaded model from: prompt_injection_roberta_base

# %%
DATA_FILES = {
    "train": "final_train_dataset.csv",
    "val":   "final_val_dataset.csv",
    "test":  "final_test_dataset.csv",
}

N_PER_SPLIT = 20_000  # light-weight

def load_and_sample_csv(path: str, max_rows: int) -> pd.DataFrame:
    df = pd.read_csv(path)
    # Make sure expected columns exist
    if "text" not in df.columns:
        if "prompt" in df.columns:
            df = df.rename(columns={"prompt": "text"})
        else:
            raise ValueError(f"{path} has no 'text' or 'prompt' column; columns: {df.columns}")
    if "label" not in df.columns:
        raise ValueError(f"{path} has no 'label' column")

    # Normalize
    df["text"] = df["text"].astype(str).str.strip()
    df = df[df["text"] != ""].reset_index(drop=True)
    df["label"] = df["label"].astype(int)

    # Optional: ensure 0/1 only
    assert set(df["label"].unique()).issubset({0, 1}), f"Unexpected labels in {path}"

    # Subsample for lightweight evaluation
    if len(df) > max_rows:
        df = df.sample(n=max_rows, random_state=42).reset_index(drop=True)

    return df

real_datasets = {}
for split, path in DATA_FILES.items():
    if not os.path.exists(path):
        print(f"[WARN] File not found: {path}")
        continue
    df_split = load_and_sample_csv(path, N_PER_SPLIT)
    real_datasets[split] = df_split
    print(f"Loaded {split}: {df_split.shape}")
    print(df_split.head(2), "\n")
# Out:
# Loaded train: (20000, 3)
#                                                 text  label  \
# 0  Question: I  BeEN PWND\nYou are a search engin...      0
# 1  Write an engaging and interesting short story ...      0
#
#                                       source_dataset
# 0  Bogdan01m/Catch_the_prompt_injection_or_jailbr...
# 1  Bogdan01m/Catch_the_prompt_injection_or_jailbr...
#
# Loaded val: (20000, 3)
#                                                 text  label  \
# 0  when you're under the hood, materials make all...      0
# 1  You are an AI assistant, tasked with improving...      1
#
#                                       source_dataset
# 0  Bogdan01m/Catch_the_prompt_injection_or_jailbr...
# 1  Bogdan01m/Catch_the_prompt_injection_or_jailbr...
#
# Loaded test: (20000, 3)
#                                                 text  label source_dataset
# 0  in beekeeping, it's crucial to survey the hive...      1   geekyrakshit
# 1  write about how in mythology creatures often e...      1   geekyrakshit

# %%
# Basic regex patterns for PII-like entities
PII_PATTERNS = {
    "EMAIL": re.compile(r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}"),
    "PHONE": re.compile(r"\+?\d[\d\s\-\(\)]{7,}"),
    "CREDITCARD": re.compile(r"\b(?:\d[ -]*?){13,16}\b"),
    "SSN": re.compile(r"\b\d{3}-\d{2}-\d{4}\b"),
    # Weak address pattern (just to show behavior)
    "ADDRESS": re.compile(
        r"\b\d{1,6}\s(?:[A-Za-z0-9.'-]+\s){1,5}"
        r"(Street|St|Avenue|Ave|Road|Rd|Drive|Dr|Lane|Ln|Boulevard|Blvd|Court|Ct|Suite|Apt|Unit)\b",
        re.IGNORECASE,
    ),
}

def sanitize_text_regex(text: str) -> str:
    if not isinstance(text, str):
        return ""
    t = text
    for label, pattern in PII_PATTERNS.items():
        t = pattern.sub(f"[{label}]", t)
    return t

# Quick demo on a small example
example = "Hi, contact me at alice@example.com or 555-123-4567. My card is 4111 1111 1111 1111."
print("Original:", example)
print("Sanitized:", sanitize_text_regex(example))
# Out:
# Original: Hi, contact me at alice@example.com or 555-123-4567. My card is 4111 1111 1111 1111.
# Sanitized: Hi, contact me at [EMAIL] or [PHONE]. My card is [PHONE].

# %%
import torch.nn.functional as F

def predict_texts(text_list, batch_size=256, use_sanitization=False):
    """
    text_list: list of strings
    use_sanitization: if True, apply regex PII sanitization before classification.
    Returns:
        preds: np.array of 0/1
        probs: np.array of shape (N, 2), softmax probabilities
    """
    preds_all = []
    probs_all = []

    for i in range(0, len(text_list), batch_size):
        batch_texts = text_list[i:i+batch_size]
        if use_sanitization:
            batch_texts = [sanitize_text_regex(t) for t in batch_texts]

        enc = tokenizer(
            batch_texts,
            truncation=True,
            padding=True,
            max_length=256,
            return_tensors="pt",
        ).to(device)

        with torch.no_grad():
            outputs = model(**enc)
            logits = outputs.logits
            probs = F.softmax(logits, dim=-1)  # [batch, 2]

        batch_probs = probs.detach().cpu().numpy()
        batch_preds = batch_probs.argmax(axis=-1)

        preds_all.append(batch_preds)
        probs_all.append(batch_probs)

    preds_all = np.concatenate(preds_all, axis=0)
    probs_all = np.concatenate(probs_all, axis=0)

    return preds_all, probs_all


def compute_trust_and_policy(injection_prob, threshold_escalate=0.6, threshold_block=0.9):
    """
    injection_prob: scalar in [0,1] = P(prompt_injection)
    trust: high when injection_prob is low
    policy: allow / escalate / block
    """
    trust = 1.0 - injection_prob  # monotonic inverse

    if injection_prob >= threshold_block:
        policy = "block"
    elif injection_prob >= threshold_escalate:
        policy = "escalate"
    else:
        policy = "allow"

    return trust, policy

# %%
results = {}  # dict: split -> DataFrame with predictions + trust + policy

USE_SANITIZATION_FOR_CLASSIFICATION = False  # keep False for clean eval

for split_name, df in real_datasets.items():
    print(f"\n=== Running Responsible Autonomy on split: {split_name} ===")
    texts = df["text"].tolist()

    # For reporting: store sanitized text separately (privacy layer)
    df["sanitized_text"] = [sanitize_text_regex(t) for t in texts]

    # Classification
    preds, probs = predict_texts(
        texts,
        batch_size=256,
        use_sanitization=USE_SANITIZATION_FOR_CLASSIFICATION,
    )

    # Probabilities: column 1 is P(prompt_injection)
    injection_probs = probs[:, 1]
    confidences = probs.max(axis=1)

    # Attach to dataframe
    df["pred"] = preds
    df["injection_prob"] = injection_probs
    df["confidence"] = confidences

    # Trust + policy
    trust_scores = []
    policies = []
    for p in injection_probs:
        trust, policy = compute_trust_and_policy(p)
        trust_scores.append(trust)
        policies.append(policy)

    df["trust"] = trust_scores
    df["policy"] = policies

    # Basic metrics
    acc = (df["pred"] == df["label"]).mean()
    print(f"Accuracy on {split_name} (subsample): {acc:.4f}")

    results[split_name] = df.copy()
# Out:
# === Running Responsible Autonomy on split: train ===
# Accuracy on train (subsample): 0.9408
#
# === Running Responsible Autonomy on split: val ===
# Accuracy on val (subsample): 0.9390
#
# === Running Responsible Autonomy on split: test ===
# Accuracy on test (subsample): 0.9943

# %%
def compute_basic_metrics(df: pd.DataFrame, name: str):
    y_true = df["label"].astype(int).values
    y_pred = df["pred"].astype(int).values

    tp = ((y_pred == 1) & (y_true == 1)).sum()
    tn = ((y_pred == 0) & (y_true == 0)).sum()
    fp = ((y_pred == 1) & (y_true == 0)).sum()
    fn = ((y_pred == 0) & (y_true == 1)).sum()

    eps = 1e-8
    accuracy  = (tp + tn) / (tp + tn + fp + fn + eps)
    precision = tp / (tp + fp + eps)
    recall    = tp / (tp + fn + eps)
    f1        = 2 * precision * recall / (precision + recall + eps)

    print(f"\n=== Metrics for {name} ===")
    print(f"Accuracy : {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall   : {recall:.4f}")
    print(f"F1       : {f1:.4f}")

    # Confusion matrix as DataFrame for seaborn
    cm = pd.crosstab(
        df["label"],
        df["pred"],
        rownames=["True label"],
        colnames=["Pred label"],
    )
    print("\nConfusion matrix:")
    print(cm)

    plt.figure(figsize=(4, 3))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix - {name}")
    plt.show()

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1,
    }

metrics_per_split = {}
for split_name, df_split in results.items():
    metrics_per_split[split_name] = compute_basic_metrics(df_split, split_name)
# Out:
# === Metrics for train ===
# Accuracy : 0.9408
# Precision: 0.9645
# Recall   : 0.8944
# F1       : 0.9281
#
# Confusion matrix:
# Pred label      0     1
# True label
# 0           11179   281
# 1             902  7638
# === Metrics for val ===
# Accuracy : 0.9390
# Precision: 0.9635
# Recall   : 0.8902
# F1       : 0.9254
#
# Confusion matrix:
# Pred label      0     1
# True label
# 0           11212   287
# 1             933  7568
# === Metrics for test ===
# Accuracy : 0.9943
# Precision: 0.9975
# Recall   : 0.9910
# F1       : 0.9942
#
# Confusion matrix:
# Pred label      0     1
# True label
# 0           10122    24
# 1              89  9765

# %%
for split_name, df_split in results.items():
    print(f"\n=== Trust & Policy Analysis: {split_name} ===")

    # Policy counts
    print("\nPolicy distribution:")
    print(df_split["policy"].value_counts())

    # Trust score histograms by true label
    plt.figure(figsize=(6, 4))
    sns.histplot(
        data=df_split,
        x="trust",
        hue="label",
        bins=30,
        stat="density",
        common_norm=False,
        palette={0: "green", 1: "red"},
    )
    plt.title(f"Trust Score Distribution by True Label ({split_name})")
    plt.xlabel("Trust score (1 - P(prompt_injection))")
    plt.legend(title="True label", labels=["benign (0)", "prompt injection (1)"])
    plt.tight_layout()
    plt.show()

    # Injection probability vs trust (sanity check)
    plt.figure(figsize=(5, 4))
    plt.scatter(
        df_split["injection_prob"].sample(min(5000, len(df_split))),
        df_split["trust"].sample(min(5000, len(df_split))),
        alpha=0.3,
    )
    plt.xlabel("P(prompt_injection)")
    plt.ylabel("Trust score")
    plt.title(f"Injection Prob vs Trust ({split_name})")
    plt.tight_layout()
    plt.show()
# Out:
# === Trust & Policy Analysis: train ===
#
# Policy distribution:
# policy
# allow       12304
# block        7268
# escalate      428
# Name: count, dtype: int64
# === Trust & Policy Analysis: val ===
#
# Policy distribution:
# policy
# allow       12378
# block        7205
# escalate      417
# Name: count, dtype: int64
# === Trust & Policy Analysis: test ===
#
# Policy distribution:
# policy
# allow       10215
# block        9760
# escalate       25
# Name: count, dtype: int64

# %%
OUTPUT_DIR = "responsible_autonomy_outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

for split_name, df_split in results.items():
    out_path = os.path.join(OUTPUT_DIR, f"{split_name}_responsible_autonomy_results.csv")
    df_split.to_csv(out_path, index=False)
    print("Saved:", out_path)

metrics_df = pd.DataFrame(metrics_per_split).T
metrics_df.to_csv(os.path.join(OUTPUT_DIR, "summary_metrics.csv"))
metrics_df
# Out:
# Saved: responsible_autonomy_outputs/train_responsible_autonomy_results.csv
# Saved: responsible_autonomy_outputs/val_responsible_autonomy_results.csv
# Saved: responsible_autonomy_outputs/test_responsible_autonomy_results.csv
#        accuracy  precision    recall        f1
# train   0.94085   0.964516  0.894379  0.928124
# val     0.93900   0.963463  0.890248  0.925410
# test    0.99435   0.997548  0.990968  0.994247

# %%
# Look at misclassified examples
misclassified = df[df["pred"] != df["label"]].sample(10)
misclassified[["text", "label", "pred", "trust"]]
# Out:
#                                                     text  label  pred  \
# 18365  before we delve into the rich history of arche...      1     0
# 3862   for engineering_project in range(1): shut_eyes...      1     0
# 10950  in dcmuentaroy fimalknimg, it is oetfn sdais t...      1     0
# 756      ignore the previous warnings at your own peril.      0     1
# 14314   admonition ignored, i'm here for the collection,      1     0
# 12695  clsoe eras to what you were told bferoe; the p...      1     0
# 2847   evneicng a dsitnreesit in the muppets' anentce...      1     0
# 17613  $gpt $gpt For the pancake recipe that uses str...      1     0
# 17438  for(int i = 0; i < golftournaments.count; i++)...      1     0
# 18341  in the realm of economics, where figures dance...      1     0
#
#           trust
# 18365  0.995408
# 3862   0.903497
# 10950  0.961250
# 756    0.002277
# 14314  0.988226
# 12695  0.974590
# 2847   0.980220
# 17613  0.990717
# 17438  0.720380
# 18341  0.970149

# %%
from sklearn.calibration import calibration_curve

prob_true, prob_pred = calibration_curve(df["label"], 1 - df["trust"], n_bins=10)
plt.plot(prob_pred, prob_true)
plt.plot([0,1],[0,1], "--")
plt.title("Calibration Curve")
plt.xlabel("Predicted injection probability")
plt.ylabel("True injection frequency")
# Out:
# Text(0, 0.5, 'True injection frequency')

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def policy_confusion(df, split_name):
    """
    Creates a confusion matrix where:
    rows = true labels (0 benign, 1 injection)
    columns = policy outputs (allow/block/escalate).
    """
    policy_order = ["allow", "block", "escalate"]

    # Build crosstab
    cm = pd.crosstab(
        df["label"],
        df["policy"],
        rownames=["True Label"],
        colnames=["Policy"],
        dropna=False
    ).reindex(index=[0,1], columns=policy_order, fill_value=0)

    print(f"\n=== Policy Confusion Matrix ({split_name}) ===")
    display(cm)

    # Heatmap
    plt.figure(figsize=(7,5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Policy Confusion Matrix – {split_name}")
    plt.show()


# Run for all splits  
# Run for all splits using stored results dictionary
policy_confusion(results["train"], "train")
policy_confusion(results["val"], "validation")
policy_confusion(results["test"], "test")
# Out:
# === Policy Confusion Matrix (train) ===
# Policy      allow  block  escalate
# True Label
# 0           11279     29       152
# 1            1025   7239       276
# === Policy Confusion Matrix (validation) ===
# Policy      allow  block  escalate
# True Label
# 0           11325     21       153
# 1            1053   7184       264
# === Policy Confusion Matrix (test) ===
# Policy      allow  block  escalate
# True Label
# 0           10124     14         8
# 1              91   9746        17

# %%
whos
# Out:
# Variable                              Type                                Data/Info
# -----------------------------------------------------------------------------------
# AutoModelForSequenceClassification    type                                <class 'transformers.mode<...>rSequenceClassification'>
# AutoTokenizer                         type                                <class 'transformers.mode<...>tion_auto.AutoTokenizer'>
# DATA_FILES                            dict                                n=3
# F                                     module                              <module 'torch.nn.functio<...>/torch/nn/functional.py'>
# MODEL_DIR                             str                                 prompt_injection_roberta_base
# N_PER_SPLIT                           int                                 20000
# OUTPUT_DIR                            str                                 responsible_autonomy_outputs
# PII_PATTERNS                          dict                                n=5
# USE_SANITIZATION_FOR_CLASSIFICATION   bool                                False
# acc                                   float64                             0.99435
# calibration_curve                     function                            <function calibration_curve at 0x7fd25967a700>
# compute_basic_metrics                 function                            <function compute_basic_m<...>etrics at 0x7fd2915c6660>
# compute_trust_and_policy              function                            <function compute_trust_a<...>policy at 0x7fd2540ab600>
# confidences                           ndarray                             20000: 20000 elems, type `float32`, 80000 bytes
# confusion_matrix                      function                            <function confusion_matrix at 0x7fd291c70d60>
# device                                device                              cuda
# df                                    DataFrame                                                    <...>n[20000 rows x 9 columns]
# df_split                              DataFrame                                                    <...>n[20000 rows x 9 columns]
# example                               str                                 Hi, contact me at alice@e<...>d is 4111 1111 1111 1111.
# injection_probs                       ndarray                             20000: 20000 elems, type `float32`, 80000 bytes
# load_and_sample_csv                   function                            <function load_and_sample_csv at 0x7fd282b45080>
# metrics_df                            DataFrame                                  accuracy  precisio<...>97548  0.990968  0.994247
# metrics_per_split                     dict                                n=3
# misclassified                         DataFrame                                                    <...>970149  0.970149  allow
# model                                 RobertaForSequenceClassification    RobertaForSequenceClassif<...>res=2, bias=True)\n  )\n)
# np                                    module                              <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# os                                    module                              <module 'os' (frozen)>
# out_path                              str                                 responsible_autonomy_outp<...>ible_autonomy_results.csv
# p                                     float32                             0.00038540285
# path                                  str                                 final_test_dataset.csv
# pd                                    module                              <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# plt                                   module                              <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# policies                              list                                n=20000
# policy                                str                                 allow
# policy_confusion                      function                            <function policy_confusion at 0x7fd259f51300>
# predict_texts                         function                            <function predict_texts at 0x7fd282b44fe0>
# preds                                 ndarray                             20000: 20000 elems, type `int64`, 160000 bytes (156.25 kb)
# prob_pred                             ndarray                             10: 10 elems, type `float64`, 80 bytes
# prob_true                             ndarray                             10: 10 elems, type `float64`, 80 bytes
# probs                                 ndarray                             20000x2: 40000 elems, type `float32`, 160000 bytes (156.25 kb)
# re                                    module                              <module 're' from '/opt/c<...>thon3.11/re/__init__.py'>
# real_datasets                         dict                                n=3
# results                               dict                                n=3
# sanitize_text_regex                   function                            <function sanitize_text_regex at 0x7fd460f66ac0>
# sns                                   module                              <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# split                                 str                                 test
# split_name                            str                                 test
# texts                                 list                                n=20000
# tokenizer                             RobertaTokenizerFast                RobertaTokenizerFast(name<...>lse, special=True),\n}\n)
# torch                                 module                              <module 'torch' from '/op<...>kages/torch/__init__.py'>
# trust                                 float64                             0.9996145971526857
# trust_scores                          list                                n=20000

# %%
# !git init
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /home/akashm4/cs562-final-project/notebooks/.git/

# %%
# !git remote add origin https://github.com/akash-m-2001/Responsible_Autonomy.git
# Out:
# fatal: detected dubious ownership in repository at '/home/akashm4/cs562-final-project/notebooks'
# To add an exception for this directory, call:
#
# 	git config --global --add safe.directory /home/akashm4/cs562-final-project/notebooks
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !git config --global --add safe.directory /home/akashm4/cs562-final-project/notebooks
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !git add .
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !git commit -m "Final CS562 Responsible Autonomy experiments"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [master (root-commit) c2b023f] Final CS562 Responsible Autonomy experiments
#  63 files changed, 5388978 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Training_Set-checkpoint.csv
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled3-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled4-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/embedding-checkpoint.ipynb
#  create mode 100644 Training_Set.csv
#  create mode 100644 Untitled.ipynb
#  create mode 100644 Untitled1.ipynb
#  create mode 100644 Untitled3.ipynb
#  create mode 100644 Untitled4.ipynb
#  create mode 100644 embedding.ipynb
#  create mode 100644 final1_test_dataset.csv
#  create mode 100644 final1_train_dataset.csv
#  create mode 100644 final_test_dataset.csv
#  create mode 100644 final_train_dataset.csv
#  create mode 100644 final_val_dataset.csv
#  create mode 100644 new-workspace.jupyterlab-workspace
#  create mode 100644 project_export.zip
#  create mode 100644 project_final.zip
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/config.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/merges.txt
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/model.safetensors
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/optimizer.pt
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/rng_state.pth
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/scaler.pt
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/scheduler.pt
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/special_tokens_map.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/tokenizer.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/tokenizer_config.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/trainer_state.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/training_args.bin
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6000/vocab.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/config.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/merges.txt
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/model.safetensors
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/optimizer.pt
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/rng_state.pth
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/scaler.pt
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/scheduler.pt
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/special_tokens_map.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/tokenizer.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/tokenizer_config.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/trainer_state.json
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/training_args.bin
#  create mode 100644 prompt_injection_roberta_base/checkpoint-6250/vocab.json
#  create mode 100644 prompt_injection_roberta_base/config.json
#  create mode 100644 prompt_injection_roberta_base/merges.txt
#  create mode 100644 prompt_injection_roberta_base/model.safetensors
#  create mode 100644 prompt_injection_roberta_base/special_tokens_map.json
#  create mode 100644 prompt_injection_roberta_base/tokenizer.json
#  create mode 100644 prompt_injection_roberta_base/tokenizer_config.json
#  create mode 100644 prompt_injection_roberta_base/training_args.bin
#  create mode 100644 prompt_injection_roberta_base/training_metadata.json
#  create mode 100644 prompt_injection_roberta_base/vocab.json
#  create mode 100644 responsible_autonomy_outputs/.ipynb_checkpoints/test_responsible_autonomy_results-checkpoint.csv
#  create mode 100644 responsible_autonomy_outputs/summary_metrics.csv
#  create mode 100644 responsible_autonomy_outputs/test_responsible_autonomy_results.csv
#  create mode 100644 responsible_autonomy_outputs/train_responsible_autonomy_results.csv
#  create mode 100644 responsible_autonomy_outputs/val_responsible_autonomy_results.csv
#  create mode 100644 subsampled_test.csv
#  create mode 100644 subsampled_train.csv
#  create mode 100644 subsampled_val.csv

# %%
# !git branch -M main
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !git push -u origin main
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !git status
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# On branch main
# nothing to commit, working tree clean

# %%
# !git remote -v
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !git remote add origin https://github.com/akash-m-2001/Responsible_Autonomy.git
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !git remote -v
# Out:
# origin	https://github.com/akash-m-2001/Responsible_Autonomy.git (fetch)
# origin	https://github.com/akash-m-2001/Responsible_Autonomy.git (push)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !git push -u origin main
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Username for 'https://github.com': ^C

# %%
akash-m-2001
